# %% [markdown]
# ### Data Ingestion

# %%
### Document Structure

from langchain_core.documents import Document

# %%
doc = Document(
    page_content = "This is a langchain document",
    metadata = {
        "author": "Pawneet Singh",
        "pages": 1,
        "source": "example.txt"
    }
)

print(doc)
# Out:
# page_content='This is a langchain document' metadata={'author': 'Pawneet Singh', 'pages': 1, 'source': 'example.txt'}

# %%
### Text Loader

from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
document = loader.load()

print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python is one of the most popular and versatile programming languages in the world today. It was created by Guido van Rossum in the early 1990s with a simple yet powerful vision: to make programming easy to read, easy to learn, and fun to write. Unlike languages filled with symbols, brackets, and dense syntax, Python feels almost like plain English. Its simplicity hides an incredible amount of power.\n\nThe name “Python” wasn’t inspired by the snake but by the British comedy show Monty Python’s Flying Circus. Guido, the creator, wanted a name that reflected his goal — programming should be playful, not painful. Over the decades, that philosophy has attracted millions of developers, scientists, and hobbyists to the language.\n\nAt its heart, Python is an interpreted, high-level language. That means you don’t need to compile it before running; the interpreter reads and executes your code line by line. This makes experimenting fast and feedback immediate — perfect for learning, prototyping, and problem-solving.\n\nPython emphasizes readability. Instead of curly braces or semicolons, Python uses indentation — spaces and tabs — to define blocks of code. This forces developers to write code that is clean and consistent. A Python script often looks like neatly written pseudocode, which is one reason it’s widely used in education and research.\n\nAnother defining feature is its dynamic typing. In many languages, you must explicitly declare variable types. In Python, you can simply write x = 10, and the interpreter understands that x is an integer. Later, if you reassign x = "Hello", Python adapts — the type changes automatically. This flexibility allows you to focus on solving problems instead of worrying about rigid type declarations.\n\nPython is both simple and powerful because of its extensive standard library. Almost anything you can imagine — from file handling, web requests, and data serialization to mathematical operations — has a built-in module ready to use. It’s often said that “Python comes with batteries included,” meaning that most essential tools are already part of the language.\n\nThe language supports multiple programming paradigms. You can write procedural code like in C, adopt an object-oriented approach with classes and inheritance, or even embrace functional programming using higher-order functions and immutability. Python gives you the freedom to choose the best style for your problem.\n\nPython is cross-platform and open source. It runs on Windows, macOS, and Linux, and you can freely modify or distribute it. Its open ecosystem is maintained by a global community that constantly contributes libraries, frameworks, and tools. This collective effort has made Python the foundation for many modern technologies.\n\nBecause of its simplicity and flexibility, Python is used almost everywhere. It powers web applications through frameworks like Django and Flask. It’s the backbone of data science, used by analysts and researchers with libraries such as Pandas, NumPy, and Matplotlib. It drives artificial intelligence and machine learning with TensorFlow and PyTorch. It’s also a favorite in automation, DevOps, and scripting — making everyday tasks effortless.\n\nPython’s syntax encourages clarity and structure. A simple “Hello, World!” program can be written in one line. A complex AI model might take thousands, yet the underlying readability remains. That consistency across scales is part of its magic.\n\nWhen you open a Python file, you’re not just writing instructions for a computer — you’re expressing logic in one of the cleanest forms possible. Code feels like conversation: direct, structured, and expressive. Beginners find it approachable, while experts appreciate its depth.\n\nAs you progress, you’ll learn about variables, loops, conditionals, and functions — the building blocks of any program. You’ll explore lists, tuples, dictionarie ...

# %%
## Directory Loader

from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader(
    "../data/text_files",
    glob = "**/*.txt",
    loader_cls = TextLoader,
    loader_kwargs = {"encoding": "utf-8"},
    show_progress = False
)

documents = dir_loader.load()
print(documents)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python is one of the most popular and versatile programming languages in the world today. It was created by Guido van Rossum in the early 1990s with a simple yet powerful vision: to make programming easy to read, easy to learn, and fun to write. Unlike languages filled with symbols, brackets, and dense syntax, Python feels almost like plain English. Its simplicity hides an incredible amount of power.\n\nThe name “Python” wasn’t inspired by the snake but by the British comedy show Monty Python’s Flying Circus. Guido, the creator, wanted a name that reflected his goal — programming should be playful, not painful. Over the decades, that philosophy has attracted millions of developers, scientists, and hobbyists to the language.\n\nAt its heart, Python is an interpreted, high-level language. That means you don’t need to compile it before running; the interpreter reads and executes your code line by line. This makes experimenting fast and feedback immediate — perfect for learning, prototyping, and problem-solving.\n\nPython emphasizes readability. Instead of curly braces or semicolons, Python uses indentation — spaces and tabs — to define blocks of code. This forces developers to write code that is clean and consistent. A Python script often looks like neatly written pseudocode, which is one reason it’s widely used in education and research.\n\nAnother defining feature is its dynamic typing. In many languages, you must explicitly declare variable types. In Python, you can simply write x = 10, and the interpreter understands that x is an integer. Later, if you reassign x = "Hello", Python adapts — the type changes automatically. This flexibility allows you to focus on solving problems instead of worrying about rigid type declarations.\n\nPython is both simple and powerful because of its extensive standard library. Almost anything you can imagine — from file handling, web requests, and data serialization to mathematical operations — has a built-in module ready to use. It’s often said that “Python comes with batteries included,” meaning that most essential tools are already part of the language.\n\nThe language supports multiple programming paradigms. You can write procedural code like in C, adopt an object-oriented approach with classes and inheritance, or even embrace functional programming using higher-order functions and immutability. Python gives you the freedom to choose the best style for your problem.\n\nPython is cross-platform and open source. It runs on Windows, macOS, and Linux, and you can freely modify or distribute it. Its open ecosystem is maintained by a global community that constantly contributes libraries, frameworks, and tools. This collective effort has made Python the foundation for many modern technologies.\n\nBecause of its simplicity and flexibility, Python is used almost everywhere. It powers web applications through frameworks like Django and Flask. It’s the backbone of data science, used by analysts and researchers with libraries such as Pandas, NumPy, and Matplotlib. It drives artificial intelligence and machine learning with TensorFlow and PyTorch. It’s also a favorite in automation, DevOps, and scripting — making everyday tasks effortless.\n\nPython’s syntax encourages clarity and structure. A simple “Hello, World!” program can be written in one line. A complex AI model might take thousands, yet the underlying readability remains. That consistency across scales is part of its magic.\n\nWhen you open a Python file, you’re not just writing instructions for a computer — you’re expressing logic in one of the cleanest forms possible. Code feels like conversation: direct, structured, and expressive. Beginners find it approachable, while experts appreciate its depth.\n\nAs you progress, you’ll learn about variables, loops, conditionals, and functions — the building blocks of any program. You’ll explore lists, tuples, dictionarie ...

# %%
from langchain_community.document_loaders import PyMuPDFLoader

dir_loader = DirectoryLoader(
    "../data/pdf",
    glob = "**/*.pdf",
    loader_cls = PyMuPDFLoader,
    show_progress = False
)

pdf_documents = dir_loader.load()
print(pdf_documents)
# Out:
# [Document(metadata={'producer': 'Skia/PDF m141', 'creator': 'FlowCV - https://flowcv.com', 'creationdate': '2025-10-23T10:39:36+00:00', 'source': '../data/pdf/Pawneet_Singh_Staff_Engineer_AI_Architect_Resume.pdf', 'file_path': '../data/pdf/Pawneet_Singh_Staff_Engineer_AI_Architect_Resume.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': 'FlowCV – Online Resume Builder – https://flowcv.com', 'moddate': '2025-10-23T10:39:36+00:00', 'trapped': '', 'modDate': "D:20251023103936+00'00'", 'creationDate': "D:20251023103936+00'00'", 'page': 0}, page_content='PAWNEET SINGH\nStaff Engineer 2 & AI-Enabled Software Architect\npawneet.dev@gmail.com\n \n+91-9990997885\n \nBangalore, India\n \nlinkedin.com/in/pawneetdev\n \ngithub.com/pawneetdev\n \nSUMMARY\nStaff Engineer and Software Architect with close to 10 years of experience in software engineering, distributed \nsystems, and AI-driven development. Specialized in building scalable microservices, modernizing legacy \nplatforms, and integrating LLM-based automation and AIOps to improve reliability and engineering velocity. \nCombines deep architectural design expertise with a hands-on AI implementation mindset to create intelligent, \nhigh-performance systems.\nSKILLS\nProgramming\n•Ruby on Rails\n•Python\n•Go (Beginner)\n•SQL\nData & Infra\n•Postgres / MySQL\n•DynamoDB\n•Redis / Elastic cache\n•Kafka / SQS\n•Elasticsearch\nAI & Automation Tools\n•Amazon Bedrock (Beginner)\n•Claude / Copilot\n•OpenAI API\n•Agent & Automation tools\nFrameworks & Utilities\n•Docker\n•Nginx\n•Cloudflare\n•Kubernetes\n•Streamlit\nAI Concepts\n•Retrieval-Augmented \nGeneration (RAG) (Beginner)\n•Prompt Engineering\n•AI Agents\n•LLM Integration\n•GenAI Automation\nCloud Platforms\n•AWS\n•GCP\nEXPERIENCE\n11/2021 – Present\nBengaluru\nStaff Engineer 2\nCoinDCX\nAI & Automation Enablement\n•Built an AI-powered Confluence Assistant using Streamlit, Amazon Bedrock, \nAmazon Kendra, and Boto3 SDK, enabling teams to query documentation in \nnatural language via RAG.\n•Drove AI-first development adoption through Copilot and Claude, improving \ndeveloper efficiency and reducing feature delivery time by ~25–30%.\n•Conducted AIOps POC in PagerDuty, implementing LLM-based signal-to-noise \nfiltering and auto-triage, achieving ~40% reduction in alert fatigue and faster \nincident response.\n•Partnered with the Marketing team on MarTech automation using OpenAI API \nand no-code tools (Make.com) to automate content creation and reporting \nworkflows, saving ~20+ hours/week across teams.'), Document(metadata={'producer': 'Skia/PDF m141', 'creator': 'FlowCV - https://flowcv.com', 'creationdate': '2025-10-23T10:39:36+00:00', 'source': '../data/pdf/Pawneet_Singh_Staff_Engineer_AI_Architect_Resume.pdf', 'file_path': '../data/pdf/Pawneet_Singh_Staff_Engineer_AI_Architect_Resume.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': 'FlowCV – Online Resume Builder – https://flowcv.com', 'moddate': '2025-10-23T10:39:36+00:00', 'trapped': '', 'modDate': "D:20251023103936+00'00'", 'creationDate': "D:20251023103936+00'00'", 'page': 1}, page_content='System Architecture & Scalability\n•Led decomposition of the monolith into microservices, designing and migrating \n18.5M users, 950M wallet transactions, and 2.72B orders with zero data loss and \ndowntime.\n•Established standard frameworks for interoperability, including centralized \nProtobuf generation, Lua-based functions in Redis, and HTTP → gRPC \ntranscoding in the API Gateway.\n•Collaborated with Data Engineering to migrate 10B+ records across DynamoDB \nand Postgres, improving scalability and reliability of trading and analytics systems.\nPerformance & Reliability\n•Optimized Futures Read APIs with 50 ms latency reduction and 12% lower \nCPU/memory usage through write-through caching and query refactoring.\n•Designed rate-limiting and order-routing logic, improving order acceptance rate \ ...

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
